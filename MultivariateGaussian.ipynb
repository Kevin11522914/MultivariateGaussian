# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
import numpy as np

# %%
x = np.linspace(0, 4, 100)
y = np.linspace(0, 4, 100)
X, Y = np.meshgrid(x, y)
pos = np.dstack((X, Y))
mu = np.array([2, 2])
cov = np.array([[.5, 0],[0, .5]])
rv = multivariate_normal(mu, cov)
Z = rv.pdf(pos)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z)
fig.show()
# Out:
# /home/sohamp/.local/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
def gaussian(x,y,mu,cov):
    X, Y = np.meshgrid(x, y)
    pos = np.dstack((X, Y))
    rv = multivariate_normal(mu, cov)
    Z = rv.pdf(pos)
    return X,Y,Z

# %% [markdown]
# # HTML Widgets

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import display
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd

# %%
def f(k,m,cov11,cov12,cov21,cov22):
    cov11=float(cov11)
    cov12=float(cov12)
    cov21=float(cov21)
    cov22=float(cov22)
    x = np.linspace(0, 10, 100)
    y = np.linspace(0, 10, 100)
    X, Y = np.meshgrid(x, y)
    pos = np.dstack((X, Y))
    mu = np.array([k,m])
    cov = np.array([[cov11, cov12],[cov21, cov22]])
    rv = multivariate_normal(mu, cov)
    Z = rv.pdf(pos)
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, Z)
    fig.show()
#     return x

# %%
interact(f, k=(0,10),m=(0,10), cov11='0.5',cov12='0',cov21='0',cov22='0.5');
# Out:
# interactive(children=(IntSlider(value=5, description='k', max=10), IntSlider(value=5, description='m', max=10), Text(value='0.5', description='cov11'), Text(value='0', description='cov12'), Text(value='0', description='cov21'), Text(value='0.5', description='cov22'), Output()), _dom_classes=('widget-interact',))

# %%
# Out:
# Saving notebook... Saved 'MultivariateGaussian.ipynb'.
# Converting notebook...
# WARNING:root:
# Error when converting :(
#
# Double check that you didn't misspell your filename. This is the filename you
# wanted to publish: MultivariateGaussian.ipynb.
#
# If you believe this is an error with the package, please report an issue at
# https://github.com/SamLau95/nbinteract/issues/new and include the error output
# below:
#
# ==============
#
# Usage:
#   nbinteract init
#   nbinteract NOTEBOOKS ...
#   nbinteract [options] NOTEBOOKS ...
#   nbinteract (-h | --help)
# [nbinteract] Spec must be in the format {username}/{repo}/{branch} but got demo.
# [nbinteract]   Exiting...
